# %%
# step 1
# Import the Librarys
import openpyxl as xl
import xlsxwriter
import pandas as pd

# %%
# step 2
# Set the Excel file path

workBook2 = 'Qualification Completion Records Report Aug,23.xlsx'
new_workbook = 'workbook.xlsx'

# step 3
# Load the sheet in an object and skip the unneeded rows
ws2 = pd.read_excel(workBook2, 1,skiprows = 3)
ws2#['Completed']
# Out:
#                            Name                  Employee  External ID  Title  \
# 0            BLS and First Aid                  Amri, Ali       101066    NaN
# 1            BLS and First Aid           Dobriyal, Sanjay       301192    NaN
# 2            BLS and First Aid            Espiritu, Eiley       302017    NaN
# 3            BLS and First Aid           Ghanmi, Abdullah       101900    NaN
# 4            BLS and First Aid             Harthi, Nawwaf       102169    NaN
# 5            BLS and First Aid              Homidi, Yaser       104079    NaN
# 6            BLS and First Aid             Khan, Muhammad       301422    NaN
# 7            BLS and First Aid            Mohammad, Hasan       301078    NaN
# 8            BLS and First Aid               Syed, Farooq       301706    NaN
# 9            BLS and First Aid               Tammar, Wael       104028    NaN
# 10  Driver Improvement Program            Balosh, Albaraa       104353    NaN
# 11  Driver Improvement Program                 Esawy, Ali       301310    NaN
# 12  Driver Improvement Program          Jamhoor, Mohammed       103236    NaN
# 13  Driver Improvement Program              Jan, Mohammed       102417    NaN
# 14  Driver Improvement Program                Jose, Bilky      7048877    NaN
# 15  Driver Improvement Program             Khan, Muhammad       301422    NaN
# 16  Driver Improvement Program            Mohammad, Hasan       301078    NaN
# 17  Driver Improvement Program            Qahtani, Hassan       104822    NaN
# 18  Driver Improvement Program           Said, Abdulrahim       103404    NaN
# 19  Driver Improvement Program              Sharit, Ahmed       104356    NaN
# 20  Driver Improvement Program               Tammar, Wael       104028    NaN
# 21      Lock Out Tag Out (LOTO)               Abas, Ahmad       103739    NaN
# 22      Lock Out Tag Out (LOTO)      Abduljabbar, Mahmoud       103740    NaN
# 23      Lock Out Tag Out (LOTO)             Amoudi, Fahad       104728    NaN
# 24      Lock Out Tag Out (LOTO)            Arkoubi, Yaser       102743    NaN
# 25      Lock Out Tag Out (LOTO)            Baleela, Rayan       105122    NaN
# 26      Lock Out Tag Out (LOTO)              Bedair, Nouf       104879    NaN
# 27      Lock Out Tag Out (LOTO)             Garni, Dhafer       105064    NaN
# 28      Lock Out Tag Out (LOTO)       Hawsawi, Abdulkader       104175    NaN
# 29      Lock Out Tag Out (LOTO)            Hubaishi, Muad       104421    NaN
# 30      Lock Out Tag Out (LOTO)         Jamhoor, Mohammed       103236    NaN
# 31      Lock Out Tag Out (LOTO)        Malki, Abdulkareem       102892    NaN
# 32      Lock Out Tag Out (LOTO)             Malki, Khalid       105124    NaN
# 33      Lock Out Tag Out (LOTO)            Mishra, Neeraj       301947    NaN
# 34      Lock Out Tag Out (LOTO)           Mohammad, Hasan       301078    NaN
# 35      Lock Out Tag Out (LOTO)          Mutwalli, Bassam       101762    NaN
# 36      Lock Out Tag Out (LOTO)              Rzki, Faisal       103792    NaN
# 37      Lock Out Tag Out (LOTO)              Saab, Hassan       101422    NaN
# 38      Lock Out Tag Out (LOTO)           Sehli, Abdullah       104737    NaN
# 39      Lock Out Tag Out (LOTO)        Shahrani, Mohammed       104816    NaN
# 40      Lock Out Tag Out (LOTO)  Shakoori, Muhammad naeem       301933    NaN
# 41      Lock Out Tag Out (LOTO)           Subhi, Mohammed       101480    NaN
# 42      Lock Out Tag Out (LOTO)              Tammar, Wael       104028    NaN
# 43      Lock Out Tag Out (LOTO)             Zubaidi, Adel       104188    NaN
#
#     Completed     Time Spent
# 0   8/23/2021     97 Minutes
# 1   8/23/2021     32 Minutes
# 2   8/23/2021     87 Minutes
# 3   8/23/2021     69 Minutes
# 4   8/23/2021     17 Minutes
# 5   8/23/2021     73 Minutes
# 6   8/23/2021    116 Minutes
# 7   8/23/2021     14 Minutes
# 8   8/23/2021    156 Minutes
# 9   8/23/2021     17 Minutes
# 10  8/23/2021     18 Minutes
# 11  8/22/2021     14 Minutes
# 12  8/23/2021     16 Minutes
# 13  8/23/2021     38 Minutes
# 14  8/23/2021     55 Minutes
# 15  8/23/2021    148 Minutes
# 16  8/23/2021     20 Minutes
# 17  8/23/2021     19 Minutes
# 18  8/23/2021    103 Minutes
# 19  8/23/2021      9 Minutes
# 20  8/23/2021     33 Minutes
# 21  8/23/2021     51 Minutes
# 22  8/23/2021     58 Minutes
# 23  8/23/2021  10269 Minutes
# 24  8/23/2021     73 Minutes
# 25  8/23/2021     50 Minutes
# 26  8/23/2021    124 Minutes
# 27  8/23/2021    131 Minutes
# 28  8/23/2021     16 Minutes
# 29  8/23/2021     16 Minutes
# 30  8/23/2021     32 Minutes
# 31  8/22/2021     56 Minutes
# 32  8/22/2021     25 Minutes
# 33  8/22/2021     58 Minutes
# 34  8/23/2021     17 Minutes
# 35  8/23/2021    289 Minutes
# 36  8/23/2021     23 Minutes
# 37  8/23/2021     60 Minutes
# 38  8/23/2021     79 Minutes
# 39  8/22/2021     59 Minutes
# 40  8/23/2021     65 Minutes
# 41  8/22/2021     26 Minutes
# 42  8/23/2021     22 Minutes
# 43  8/22/2021     28 Minutes

# %%
# step 4

# make list of the required columns names.
ws2Columns = ['Name', 'External ID', 'Completed']
ws1Columns = ['Activity', 'External ID', 'Completed']

print(type(ws2Columns))
# step 5
#make new table from the required columns
table = ws2[ws2Columns]
print(type(ws2))
# the new table
table
# Out:
# <class 'list'>
# <class 'pandas.core.frame.DataFrame'>
#                            Name  External ID  Completed
# 0            BLS and First Aid        101066  8/23/2021
# 1            BLS and First Aid        301192  8/23/2021
# 2            BLS and First Aid        302017  8/23/2021
# 3            BLS and First Aid        101900  8/23/2021
# 4            BLS and First Aid        102169  8/23/2021
# 5            BLS and First Aid        104079  8/23/2021
# 6            BLS and First Aid        301422  8/23/2021
# 7            BLS and First Aid        301078  8/23/2021
# 8            BLS and First Aid        301706  8/23/2021
# 9            BLS and First Aid        104028  8/23/2021
# 10  Driver Improvement Program        104353  8/23/2021
# 11  Driver Improvement Program        301310  8/22/2021
# 12  Driver Improvement Program        103236  8/23/2021
# 13  Driver Improvement Program        102417  8/23/2021
# 14  Driver Improvement Program       7048877  8/23/2021
# 15  Driver Improvement Program        301422  8/23/2021
# 16  Driver Improvement Program        301078  8/23/2021
# 17  Driver Improvement Program        104822  8/23/2021
# 18  Driver Improvement Program        103404  8/23/2021
# 19  Driver Improvement Program        104356  8/23/2021
# 20  Driver Improvement Program        104028  8/23/2021
# 21      Lock Out Tag Out (LOTO)       103739  8/23/2021
# 22      Lock Out Tag Out (LOTO)       103740  8/23/2021
# 23      Lock Out Tag Out (LOTO)       104728  8/23/2021
# 24      Lock Out Tag Out (LOTO)       102743  8/23/2021
# 25      Lock Out Tag Out (LOTO)       105122  8/23/2021
# 26      Lock Out Tag Out (LOTO)       104879  8/23/2021
# 27      Lock Out Tag Out (LOTO)       105064  8/23/2021
# 28      Lock Out Tag Out (LOTO)       104175  8/23/2021
# 29      Lock Out Tag Out (LOTO)       104421  8/23/2021
# 30      Lock Out Tag Out (LOTO)       103236  8/23/2021
# 31      Lock Out Tag Out (LOTO)       102892  8/22/2021
# 32      Lock Out Tag Out (LOTO)       105124  8/22/2021
# 33      Lock Out Tag Out (LOTO)       301947  8/22/2021
# 34      Lock Out Tag Out (LOTO)       301078  8/23/2021
# 35      Lock Out Tag Out (LOTO)       101762  8/23/2021
# 36      Lock Out Tag Out (LOTO)       103792  8/23/2021
# 37      Lock Out Tag Out (LOTO)       101422  8/23/2021
# 38      Lock Out Tag Out (LOTO)       104737  8/23/2021
# 39      Lock Out Tag Out (LOTO)       104816  8/22/2021
# 40      Lock Out Tag Out (LOTO)       301933  8/23/2021
# 41      Lock Out Tag Out (LOTO)       101480  8/22/2021
# 42      Lock Out Tag Out (LOTO)       104028  8/23/2021
# 43      Lock Out Tag Out (LOTO)       104188  8/22/2021

# %%
# step 6
# Convert the pivot column(Activity or Name) to list (this part used to help filtring the courses na)
nameList = table['Name'].to_list()
nameList
# Out:
# ['Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Supported Scaffold Safety (Version 1.2)',
#  'Activity Descr.',
#  'This course covers some of the more important OSHA requirements for supported scaffolds, as well as basic safe practices for working on or near these scaffolds. It is intended as an introductory or refresher course for construction and general industry workers who will be working on or near scaffold systems.',
#  nan,
#  nan]

# %%
# step 7
# exctractingCoursesNames function exctract the courses names to nameList to help in the filtering part

def exctractingCoursesNames(list):
    n = len(list)
    newList = []
    for i in range(0,n):
        if i == 0 :
            newList.append(list[i])
            
        elif i > 0 :
            if list[i] == list[i-1]:
               
                continue
            else:
                     newList.append(list[i]) 
                     
    return  newList         
        
coursesList = exctractingCoursesNames(nameList)   
coursesList
# Out:
# ['Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Confined Space Entry - Permit Required (Version 1.1)',
#  'Activity Descr.',
#  'A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Electrical Safety General Awareness (Version 1.1)',
#  'Activity Descr.',
#  'Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Fire Extinguisher Safety (Version 1.1)',
#  'Activity Descr.',
#  'We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.',
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hazard Communication GHS (Version 1.1)',
#  'Activity Descr.',
#  nan,
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Hydrogen Sulfide Awareness (Version 1.1)',
#  'Activity Descr.',
#  "Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.",
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Process Safety Management (Version 1.1)',
#  'Activity Descr.',
#  'Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.',
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Radiation Safety (Version 1.1)',
#  'Activity Descr.',
#  "The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!",
#  'Supported Scaffold Safety (Version 1.2)',
#  'Activity Descr.',
#  'This course covers some of the more important OSHA requirements for supported scaffolds, as well as basic safe practices for working on or near these scaffolds. It is intended as an introductory or refresher course for construction and general industry workers who will be working on or near scaffold systems.',
#  nan,
#  nan]

# %%
# here the courses names list we talked about before.

for i in range(len(coursesList)):
    #print('\nCourses: \n',coursesList)
    print(i+1,'-',coursesList[i])
# Out:
# 1 - Confined Space Entry - Permit Required (Version 1.1)
# 2 - Activity Descr.
# 3 - A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.
# 4 - Confined Space Entry - Permit Required (Version 1.1)
# 5 - Activity Descr.
# 6 - A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.
# 7 - Confined Space Entry - Permit Required (Version 1.1)
# 8 - Activity Descr.
# 9 - A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.
# 10 - Confined Space Entry - Permit Required (Version 1.1)
# 11 - Activity Descr.
# 12 - A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.
# 13 - Confined Space Entry - Permit Required (Version 1.1)
# 14 - Activity Descr.
# 15 - A confined space is defined as a work area which has sufficient space for a person to fit within and perform work, limited means of entry and exit, and a design that was not intended for continuous worker occupancy. Working in a confined space can present hazardous atmospheres and physical dangers to employees. This course will describe the dangers, best practices, and permit requirements necessary when working in a permit-required confined space.
# 16 - Electrical Safety General Awareness (Version 1.1)
# 17 - Activity Descr.
# 18 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 19 - Electrical Safety General Awareness (Version 1.1)
# 20 - Activity Descr.
# 21 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 22 - Electrical Safety General Awareness (Version 1.1)
# 23 - Activity Descr.
# 24 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 25 - Electrical Safety General Awareness (Version 1.1)
# 26 - Activity Descr.
# 27 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 28 - Electrical Safety General Awareness (Version 1.1)
# 29 - Activity Descr.
# 30 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 31 - Electrical Safety General Awareness (Version 1.1)
# 32 - Activity Descr.
# 33 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 34 - Electrical Safety General Awareness (Version 1.1)
# 35 - Activity Descr.
# 36 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 37 - Electrical Safety General Awareness (Version 1.1)
# 38 - Activity Descr.
# 39 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 40 - Electrical Safety General Awareness (Version 1.1)
# 41 - Activity Descr.
# 42 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 43 - Electrical Safety General Awareness (Version 1.1)
# 44 - Activity Descr.
# 45 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 46 - Electrical Safety General Awareness (Version 1.1)
# 47 - Activity Descr.
# 48 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 49 - Electrical Safety General Awareness (Version 1.1)
# 50 - Activity Descr.
# 51 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 52 - Electrical Safety General Awareness (Version 1.1)
# 53 - Activity Descr.
# 54 - Spark discussion with your team on effective ways to recognize, evaluate, and avoid electrical hazards. Topics covered include personal protective equipment related to electrical safety, OSHA requirements for working on equipment, and electrical injuries such as shocks, burns, electrocutions, and falls.
# 55 - Fire Extinguisher Safety (Version 1.1)
# 56 - Activity Descr.
# 57 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 58 - Fire Extinguisher Safety (Version 1.1)
# 59 - Activity Descr.
# 60 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 61 - Fire Extinguisher Safety (Version 1.1)
# 62 - Activity Descr.
# 63 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 64 - Fire Extinguisher Safety (Version 1.1)
# 65 - Activity Descr.
# 66 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 67 - Fire Extinguisher Safety (Version 1.1)
# 68 - Activity Descr.
# 69 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 70 - Fire Extinguisher Safety (Version 1.1)
# 71 - Activity Descr.
# 72 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 73 - Fire Extinguisher Safety (Version 1.1)
# 74 - Activity Descr.
# 75 - We see them hanging on the wall every day but most people know very little about fire extinguishers. Use this fire extinguisher training course to educate your team on the fire tetrahedron, the types of fires that can occur in the workplace, and how and when to use a fire extinguisher. This course also describes when to evacuate and provides some proper maintenance tips for fire extinguishers.
# 76 - Hazard Communication GHS (Version 1.1)
# 77 - Activity Descr.
# 78 - nan
# 79 - Hazard Communication GHS (Version 1.1)
# 80 - Activity Descr.
# 81 - nan
# 82 - Hazard Communication GHS (Version 1.1)
# 83 - Activity Descr.
# 84 - nan
# 85 - Hazard Communication GHS (Version 1.1)
# 86 - Activity Descr.
# 87 - nan
# 88 - Hazard Communication GHS (Version 1.1)
# 89 - Activity Descr.
# 90 - nan
# 91 - Hydrogen Sulfide Awareness (Version 1.1)
# 92 - Activity Descr.
# 93 - Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.
# 94 - Hydrogen Sulfide Awareness (Version 1.1)
# 95 - Activity Descr.
# 96 - Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.
# 97 - Hydrogen Sulfide Awareness (Version 1.1)
# 98 - Activity Descr.
# 99 - Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.
# 100 - Hydrogen Sulfide Awareness (Version 1.1)
# 101 - Activity Descr.
# 102 - Sometimes what you can't smell can hurt you. Protect yourself and your team with this critical information that raises awareness of what Hydrogen Sulfide (H2S) is and discusses exposure risks and effects, toxicity, ignition, detection, prevention, and evacuation.
# 103 - Process Safety Management (Version 1.1)
# 104 - Activity Descr.
# 105 - Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.
# 106 - Process Safety Management (Version 1.1)
# 107 - Activity Descr.
# 108 - Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.
# 109 - Process Safety Management (Version 1.1)
# 110 - Activity Descr.
# 111 - Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.
# 112 - Process Safety Management (Version 1.1)
# 113 - Activity Descr.
# 114 - Process Safety Management is the identification, evaluation, and prevention of highly hazardous chemical releases that could occur as a result of catastrophic failures in processes, procedures, or equipment. This course covers the components of the OSHA regulation in detail. By actively participating in PSM training and following all recommended safe work practices, you can do your part to help improve safety in the workplace.
# 115 - Radiation Safety (Version 1.1)
# 116 - Activity Descr.
# 117 - The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!
# 118 - Radiation Safety (Version 1.1)
# 119 - Activity Descr.
# 120 - The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!
# 121 - Radiation Safety (Version 1.1)
# 122 - Activity Descr.
# 123 - The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!
# 124 - Radiation Safety (Version 1.1)
# 125 - Activity Descr.
# 126 - The myths surrounding radiation exposure may be great for a Hollywood screenplay, but they won't help you work safely around radiation at your facility. Use this radiation safety course to learn about ionizing and non-ionizing radiation, gamma rays, isotope encapsulation, radiation-based sensor usage, radiation strength, and exposure minimization. We're sure you'll find our radiation course a valuable asset to your safety program!
# 127 - Supported Scaffold Safety (Version 1.2)
# 128 - Activity Descr.
# 129 - This course covers some of the more important OSHA requirements for supported scaffolds, as well as basic safe practices for working on or near these scaffolds. It is intended as an introductory or refresher course for construction and general industry workers who will be working on or near scaffold systems.
# 130 - nan
# 131 - nan

# %%
# I used isin() function to create new df from the column names in the courses list
# new table to save result of the filtred data.

# filtered_table = table[table.Activity.isin(coursesList)]

# filtered_table['Activity']

# %%
# step 8
# set the dates
startDate = timestring.Date(input('Enter start Date:'))
endDate = timestring.Date(input('Enter End Date: '))
# Out:
# Enter start Date: 2021-8-1
# Enter End Date:  2021-8-31

# %%
# timestring library is a great library that converts any string to date type object. 


# filter the table by date ((NOT USED))
def filterDFDate(dataFrame, startDate, EndDate):
    
    for i in range(len(dataFrame)):
        timestring.Date(dataFrame['Completed'][i])    # convert the date from string type to date type
    dataFrame[dataFrame['Completed']>startDate]
    
    return dataFrame

# step 9

table = table[table['Completed']>startDate]
table.reset_index(drop=True) # reset the index to start from Zero insted of the defult indexes values.
# Out:
# ---------------------------------------------------------------------------
# TimestringInvalid                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16128/1687896537.py in <module>
#      13 # step 9
#      14
# ---> 15 table = table[table['Completed']>startDate]
#      16 table.reset_index(drop=True) # reset the index to start from Zero insted of the defult indexes values.
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\arraylike.py in __gt__(self, other)
#      46     @unpack_zerodim_and_defer("__gt__")
#      47     def __gt__(self, other):
# ---> 48         return self._cmp_method(other, operator.gt)
#      49
#      50     @unpack_zerodim_and_defer("__ge__")
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~\.conda\envs\myenv\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# ~\.conda\envs\myenv\lib\site-packages\timestring\Date.py in __lt__(self, other)
#     425                 return self.date < other.end.date
#     426             else:
# --> 427                 return self.__lt__(Date(other, tz=self.tz))
#     428
#     429     def __ge__(self, other):
#
# ~\.conda\envs\myenv\lib\site-packages\timestring\Date.py in __init__(self, date, offset, start_of_week, tz, verbose)
#      49                         print("Matches:\n", ''.join(["\t%s: %s\n" % (k, v) for k, v in date.items() if v]))
#      50                 else:
# ---> 51                     raise TimestringInvalid('Invalid date string >> %s' % date)
#      52
#      53                 date = dict((k, v if type(v) is str else v) for k, v in date.items() if v)
#
# TimestringInvalid: Invalid date string >> Total:

# %%
# filtered_table.rename(columns={ 'Course Name': 'Activity'}, inplace= True) # renaming the column name.

# step 10

table['External ID'] = table['External ID'].astype(int) # convert "External ID" to int.

table
# Out:
#                            Name  External ID  Completed
# 0            BLS and First Aid        101066  8/23/2021
# 1            BLS and First Aid        301192  8/23/2021
# 2            BLS and First Aid        302017  8/23/2021
# 3            BLS and First Aid        101900  8/23/2021
# 4            BLS and First Aid        102169  8/23/2021
# 5            BLS and First Aid        104079  8/23/2021
# 6            BLS and First Aid        301422  8/23/2021
# 7            BLS and First Aid        301078  8/23/2021
# 8            BLS and First Aid        301706  8/23/2021
# 9            BLS and First Aid        104028  8/23/2021
# 10  Driver Improvement Program        104353  8/23/2021
# 11  Driver Improvement Program        301310  8/22/2021
# 12  Driver Improvement Program        103236  8/23/2021
# 13  Driver Improvement Program        102417  8/23/2021
# 14  Driver Improvement Program       7048877  8/23/2021
# 15  Driver Improvement Program        301422  8/23/2021
# 16  Driver Improvement Program        301078  8/23/2021
# 17  Driver Improvement Program        104822  8/23/2021
# 18  Driver Improvement Program        103404  8/23/2021
# 19  Driver Improvement Program        104356  8/23/2021
# 20  Driver Improvement Program        104028  8/23/2021
# 21      Lock Out Tag Out (LOTO)       103739  8/23/2021
# 22      Lock Out Tag Out (LOTO)       103740  8/23/2021
# 23      Lock Out Tag Out (LOTO)       104728  8/23/2021
# 24      Lock Out Tag Out (LOTO)       102743  8/23/2021
# 25      Lock Out Tag Out (LOTO)       105122  8/23/2021
# 26      Lock Out Tag Out (LOTO)       104879  8/23/2021
# 27      Lock Out Tag Out (LOTO)       105064  8/23/2021
# 28      Lock Out Tag Out (LOTO)       104175  8/23/2021
# 29      Lock Out Tag Out (LOTO)       104421  8/23/2021
# 30      Lock Out Tag Out (LOTO)       103236  8/23/2021
# 31      Lock Out Tag Out (LOTO)       102892  8/22/2021
# 32      Lock Out Tag Out (LOTO)       105124  8/22/2021
# 33      Lock Out Tag Out (LOTO)       301947  8/22/2021
# 34      Lock Out Tag Out (LOTO)       301078  8/23/2021
# 35      Lock Out Tag Out (LOTO)       101762  8/23/2021
# 36      Lock Out Tag Out (LOTO)       103792  8/23/2021
# 37      Lock Out Tag Out (LOTO)       101422  8/23/2021
# 38      Lock Out Tag Out (LOTO)       104737  8/23/2021
# 39      Lock Out Tag Out (LOTO)       104816  8/22/2021
# 40      Lock Out Tag Out (LOTO)       301933  8/23/2021
# 41      Lock Out Tag Out (LOTO)       101480  8/22/2021
# 42      Lock Out Tag Out (LOTO)       104028  8/23/2021
# 43      Lock Out Tag Out (LOTO)       104188  8/22/2021

# %%
# step 11 
# Create new dataframe for each course and save into list of dataframes called {finalTable}.


finalTable = {} # this list contains dataframe for each course in {coursesList}.

# this loop takes courses names from {coursesList} to varible then use the name of the course to create table for that course. 
for i in range(len(coursesList)):
    CourseName = [coursesList[i]]  # this list containes name of the course. 
    
    print('Course Name: ',CourseName) # Example  ['Confined Space Entry - Permit Required']
    
    finalTable[i] = table[table.Name.isin(CourseName)] # isin() function only accept list.
    finalTable[i] = finalTable[i].reset_index(drop= True)
    
finalTable[0]
# Out:
# Course Name:  ['BLS and First Aid ']
# Course Name:  ['Driver Improvement Program ']
# Course Name:  ['Lock Out Tag Out (LOTO)']
#                  Name  External ID  Completed
# 0  BLS and First Aid        101066  8/23/2021
# 1  BLS and First Aid        301192  8/23/2021
# 2  BLS and First Aid        302017  8/23/2021
# 3  BLS and First Aid        101900  8/23/2021
# 4  BLS and First Aid        102169  8/23/2021
# 5  BLS and First Aid        104079  8/23/2021
# 6  BLS and First Aid        301422  8/23/2021
# 7  BLS and First Aid        301078  8/23/2021
# 8  BLS and First Aid        301706  8/23/2021
# 9  BLS and First Aid        104028  8/23/2021

# %%
# coursesList len() = 8, there for i want to make a dataFrame for each course name in the coursesList and this can be done like this:
# numberOfDF = len(coursesList)
# print(numberOfDF)
# dataframe_var_list = []

# this loop replacing the white spaces
for course in range(numberOfDF):
    temp = coursesList[course].replace(' ', '_') # replac all ' ' with '_'
    
    temp = temp.replace('-', '_') # Replace all '-' with '_' becaus we cannot defined variable name with '-'
    
    dataframe_var_list.append(temp)
    print('course:',dataframe_var_list[course])
print(type(dataframe_var_list[0]))
dataframe_var_list[0]
# Out:
# 3
# course: BLS_and_First_Aid_
# course: Driver_Improvement_Program_
# course: Lock_Out_Tag_Out_(LOTO)
# <class 'str'>
# 'BLS_and_First_Aid_'

# %%
# step 12

# TEST IT !!!!
# I want to make dataframe for each course

df_list = [] # df_list is list contains a 'pandas.core.frame.DataFrame' in each index

for i in range(len(finalTable)): 
    c = ['External ID']         
    ID = finalTable[i][c] # [i] is the index of the DF , and [c] is the column name to call.
    df_list.append(ID)
    df_list[i] = df_list[i].reset_index(drop=True)
    
print(type(df_list[0]))

df_list[2] # here is an example for the DF from the df_list.
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     External ID
# 0        103739
# 1        103740
# 2        104728
# 3        102743
# 4        105122
# 5        104879
# 6        105064
# 7        104175
# 8        104421
# 9        103236
# 10       102892
# 11       105124
# 12       301947
# 13       301078
# 14       101762
# 15       103792
# 16       101422
# 17       104737
# 18       104816
# 19       301933
# 20       101480
# 21       104028
# 22       104188

# %%
# step 13 
# create new excel file to write the results on it
writer = pd.ExcelWriter(new_workbook, engine='openpyxl')

# Write the DFs in the excel work book
for i in range(len(finalTable)):
    
    print(i)
    print(df_list[i],' - ', coursesList[i])
    df_list[i].to_excel(writer, sheet_name=coursesList[i][:10]) # write DF on sheet named with the first 10 charachters of Activity name
    
# Save the workbook on the excel file.
writer.save()
# Out:
# 0
#    External ID
# 0       101066
# 1       301192
# 2       302017
# 3       101900
# 4       102169
# 5       104079
# 6       301422
# 7       301078
# 8       301706
# 9       104028  -  BLS and First Aid
# 1
#     External ID
# 0        104353
# 1        301310
# 2        103236
# 3        102417
# 4       7048877
# 5        301422
# 6        301078
# 7        104822
# 8        103404
# 9        104356
# 10       104028  -  Driver Improvement Program
# 2
#     External ID
# 0        103739
# 1        103740
# 2        104728
# 3        102743
# 4        105122
# 5        104879
# 6        105064
# 7        104175
# 8        104421
# 9        103236
# 10       102892
# 11       105124
# 12       301947
# 13       301078
# 14       101762
# 15       103792
# 16       101422
# 17       104737
# 18       104816
# 19       301933
# 20       101480
# 21       104028
# 22       104188  -  Lock Out Tag Out (LOTO)
